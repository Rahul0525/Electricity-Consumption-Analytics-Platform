# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahul0525/Electricity-Consumption-Analytics-Platform/blob/main/Electricity_Consumption_Analytics_Platform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/content/Electricity_Consumption1.csv')

# %%
df1.head()
# Out:
#       Month       City                  Company  Total Monthly Hours
# 0  November  Ahmedabad          Indowind Energy                367.2
# 1      June  Ahmedabad             Orient Green               1179.0
# 2   October  Ahmedabad          Indowind Energy                477.0
# 3  December  Ahmedabad  Tata Power Company Ltd.                393.6
# 4       May  Ahmedabad         Adani Power Ltd.                672.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7022 entries, 0 to 7021
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                7022 non-null   object
#  1   City                 7020 non-null   object
#  2   Company              7022 non-null   object
#  3   Total Monthly Hours  7019 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 219.6+ KB

# %%
df1.isnull()
# Out:
#       Month   City  Company  Total Monthly Hours
# 0     False  False    False                False
# 1     False  False    False                False
# 2     False  False    False                False
# 3     False  False    False                False
# 4     False  False    False                False
# ...     ...    ...      ...                  ...
# 7017  False  False    False                False
# 7018  False  False    False                False
# 7019  False  False    False                False
# 7020  False  False    False                False
# 7021  False  False    False                False
#
# [7022 rows x 4 columns]

# %%
df1.isnull().sum()
# Out:
# Month                  0
# City                   2
# Company                0
# Total Monthly Hours    3
# dtype: int64

# %%
df1.isna()
# Out:
#       Month   City  Company  Total Monthly Hours
# 0     False  False    False                False
# 1     False  False    False                False
# 2     False  False    False                False
# 3     False  False    False                False
# 4     False  False    False                False
# ...     ...    ...      ...                  ...
# 7017  False  False    False                False
# 7018  False  False    False                False
# 7019  False  False    False                False
# 7020  False  False    False                False
# 7021  False  False    False                False
#
# [7022 rows x 4 columns]

# %%
df1.isna().sum()
# Out:
# Month                  0
# City                   2
# Company                0
# Total Monthly Hours    3
# dtype: int64

# %%
df1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7017    False
# 7018    False
# 7019    False
# 7020    False
# 7021    False
# Length: 7022, dtype: bool

# %%
df1.duplicated().sum()
# Out:
# np.int64(40)

# %%
df1 [df1.duplicated()]
# Out:
#           Month         City                  Company  Total Monthly Hours
# 348       March    Ahmedabad          Indowind Energy              712.000
# 386    December    Ahmedabad  Tata Power Company Ltd.              969.600
# 699       March      Chennai          Reliance Energy             1174.250
# 722     October      Chennai          Reliance Energy              931.000
# 804       March      Chennai          Indowind Energy             1025.500
# 936      August        Dahej          Reliance Energy              954.450
# 1102       July        Dahej  Tata Power Company Ltd.             2923.200
# 1269      April        Dahej         Adani Power Ltd.             2056.950
# 1283     August        Dahej         Adani Power Ltd.             1694.700
# 1580     August    Faridabad         Adani Power Ltd.             1590.000
# 1775        May      Gurgaon             Orient Green             1238.600
# ...

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.shape
# Out:
# (6982, 4)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6982 entries, 0 to 7021
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                6982 non-null   object
#  1   City                 6980 non-null   object
#  2   Company              6982 non-null   object
#  3   Total Monthly Hours  6979 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 272.7+ KB

# %%
df1.count()
# Out:
# Month                  6982
# City                   6980
# Company                6982
# Total Monthly Hours    6979
# dtype: int64

# %%
df1.describe()
# Out:
#        Total Monthly Hours
# count          6979.000000
# mean           1035.481122
# std             843.021446
# min              61.400000
# 25%             472.290000
# 50%             789.600000
# 75%            1304.000000
# max            6187.500000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(df1['Total Monthly Hours'])
# Out:
# /tmp/ipython-input-3405720749.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['Total Monthly Hours'])
# <Axes: xlabel='Total Monthly Hours', ylabel='Density'>

# %%
sns.histplot(df1['Total Monthly Hours'])
# Out:
# <Axes: xlabel='Total Monthly Hours', ylabel='Count'>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6982 entries, 0 to 7021
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                6982 non-null   object
#  1   City                 6980 non-null   object
#  2   Company              6982 non-null   object
#  3   Total Monthly Hours  6979 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 272.7+ KB

# %% [markdown]
# # **Question1**

# %%
#calculated the electricity bill for each row
df2 = pd.read_csv('/content/Tariff_rates.csv')

# %%
df2.head()
# Out:
#         City  TariffRate
# 0  Ahmedabad         7.9
# 1    Chennai         8.8
# 2      Dahej         7.6
# 3  Faridabad         8.1
# 4    Gurgaon         8.3

# %%
df2.tail()
# Out:
#          City  TariffRate
# 11      Noida         8.2
# 12       Pune         9.1
# 13  Ratnagiri         7.4
# 14     Shimla         7.7
# 15   Vadodara         7.8

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        16 non-null     object
#  1   TariffRate  16 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 388.0+ bytes

# %%
df2
# Out:
#            City  TariffRate
# 0     Ahmedabad         7.9
# 1       Chennai         8.8
# 2         Dahej         7.6
# 3     Faridabad         8.1
# 4       Gurgaon         8.3
# 5     Hyderabad         8.4
# 6       Kolkata         8.7
# 7        Mumbai         9.2
# 8        Nagpur         8.9
# 9   Navi Mumbai         9.3
# 10    New Delhi         8.5
# 11        Noida         8.2
# 12         Pune         9.1
# 13    Ratnagiri         7.4
# 14       Shimla         7.7
# 15     Vadodara         7.8

# %%
df1['City'].unique()
# Out:
# array(['Ahmedabad', 'Chennai', nan, 'Dahej', 'Faridabad', 'Gurgaon',
#        'Hyderabad', 'Kolkata', 'Mumbai', 'Nagpur', 'Navi Mumbai',
#        'New Delhi', 'Noida', 'Pune', 'Ratnagiri', 'Shimla', 'Vadodara'],
#       dtype=object)

# %%
df1['City'].nunique()
# Out:
# 16

# %%
pd.merge(df1,df2,on = 'City')
# Out:
#          Month       City                  Company  Total Monthly Hours  \
# 0     November  Ahmedabad          Indowind Energy               367.20
# 1         June  Ahmedabad             Orient Green              1179.00
# 2      October  Ahmedabad          Indowind Energy               477.00
# 3     December  Ahmedabad  Tata Power Company Ltd.               393.60
# 4          May  Ahmedabad         Adani Power Ltd.               672.00
# ...        ...        ...                      ...                  ...
# 6975  February   Vadodara         Adani Power Ltd.               771.12
# 6976     April   Vadodara             Orient Green              1407.60
# 6977       May   Vadodara          Indowind Energy              1768.00
# 6978    August   Vadodara             Orient Green               986.85
# 6979  November   Vadodara  Tata Power Company Ltd.               979.20
#
#       TariffRate
# 0            7.9
# 1            7.9
# 2            7.9
# 3            7.9
# ...

# %%
df1
# Out:
#          Month       City                  Company  Total Monthly Hours
# 0     November  Ahmedabad          Indowind Energy               367.20
# 1         June  Ahmedabad             Orient Green              1179.00
# 2      October  Ahmedabad          Indowind Energy               477.00
# 3     December  Ahmedabad  Tata Power Company Ltd.               393.60
# 4          May  Ahmedabad         Adani Power Ltd.               672.00
# ...        ...        ...                      ...                  ...
# 7017  February   Vadodara         Adani Power Ltd.               771.12
# 7018     April   Vadodara             Orient Green              1407.60
# 7019       May   Vadodara          Indowind Energy              1768.00
# 7020    August   Vadodara             Orient Green               986.85
# 7021  November   Vadodara  Tata Power Company Ltd.               979.20
#
# [6982 rows x 4 columns]

# %%
merge = pd.merge(df1,df2,on = 'City')

# %%
merge
# Out:
#          Month       City                  Company  Total Monthly Hours  \
# 0     November  Ahmedabad          Indowind Energy               367.20
# 1         June  Ahmedabad             Orient Green              1179.00
# 2      October  Ahmedabad          Indowind Energy               477.00
# 3     December  Ahmedabad  Tata Power Company Ltd.               393.60
# 4          May  Ahmedabad         Adani Power Ltd.               672.00
# ...        ...        ...                      ...                  ...
# 6975  February   Vadodara         Adani Power Ltd.               771.12
# 6976     April   Vadodara             Orient Green              1407.60
# 6977       May   Vadodara          Indowind Energy              1768.00
# 6978    August   Vadodara             Orient Green               986.85
# 6979  November   Vadodara  Tata Power Company Ltd.               979.20
#
#       TariffRate
# 0            7.9
# 1            7.9
# 2            7.9
# 3            7.9
# ...

# %%
merge['Electricity Bill'] = merge['Total Monthly Hours']* merge['TariffRate']

# %%
merge
# Out:
#          Month       City                  Company  Total Monthly Hours  \
# 0     November  Ahmedabad          Indowind Energy               367.20
# 1         June  Ahmedabad             Orient Green              1179.00
# 2      October  Ahmedabad          Indowind Energy               477.00
# 3     December  Ahmedabad  Tata Power Company Ltd.               393.60
# 4          May  Ahmedabad         Adani Power Ltd.               672.00
# ...        ...        ...                      ...                  ...
# 6975  February   Vadodara         Adani Power Ltd.               771.12
# 6976     April   Vadodara             Orient Green              1407.60
# 6977       May   Vadodara          Indowind Energy              1768.00
# 6978    August   Vadodara             Orient Green               986.85
# 6979  November   Vadodara  Tata Power Company Ltd.               979.20
#
#       TariffRate  Electricity Bill
# 0            7.9          2900.880
# ...

# %% [markdown]
# # Question **2**

# %%
#calculate the average monthly hours of usage for the cities in Decending order
merge.groupby()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1677651271.py in <cell line: 0>()
#       1 #calculate the average monthly hours of usage for the cities in Decending order
# ----> 2 merge.groupby()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9179
#    9180         if level is None and by is None:
# -> 9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
#    9183         return DataFrameGroupBy(
#
# TypeError: You have to supply one of 'by' and 'level'

# %%
merge.groupby('City')['Total Monthly Hours'].mean()
# Out:
# City
# Ahmedabad      1252.175297
# Chennai        1113.937884
# Dahej          1251.822270
# Faridabad      1220.659005
# Gurgaon        1467.559574
# Hyderabad      1076.999695
# Kolkata         629.435123
# Mumbai          876.044552
# Nagpur          959.219608
# Navi Mumbai     777.384615
# New Delhi      1599.586409
# Noida          1601.452851
# Pune            739.073582
# Ratnagiri       530.865809
# Shimla          313.066050
# Vadodara       1106.086869
# Name: Total Monthly Hours, dtype: float64

# %%
merge.groupby('City')['Total Monthly Hours'].mean().sort_values(ascending = False)
# Out:
# City
# Noida          1601.452851
# New Delhi      1599.586409
# Gurgaon        1467.559574
# Ahmedabad      1252.175297
# Dahej          1251.822270
# Faridabad      1220.659005
# Chennai        1113.937884
# Vadodara       1106.086869
# Hyderabad      1076.999695
# Nagpur          959.219608
# Mumbai          876.044552
# Navi Mumbai     777.384615
# Pune            739.073582
# Kolkata         629.435123
# Ratnagiri       530.865809
# Shimla          313.066050
# Name: Total Monthly Hours, dtype: float64

# %%
plt.figure(figsize=(16,6),dpi=1400)
sns.barplot(merge.groupby('City')['Total Monthly Hours'].mean().sort_values(ascending = False))
# Out:
# <Axes: xlabel='City', ylabel='Total Monthly Hours'>

# %% [markdown]
# # **Question3**

# %%
#question 3. what are the top 3 companies in terms of average monthly hours
merge.groupby('Company')['Total Monthly Hours'].mean().sort_values(ascending = False).head(3)
# Out:
# Company
# Indowind Energy            1059.862618
# Orient Green               1053.577907
# Tata Power Company Ltd.    1035.275307
# Name: Total Monthly Hours, dtype: float64

# %%
sns.barplot(merge.groupby('Company')['Total Monthly Hours'].mean().sort_values(ascending = False).head(3))
# Out:
# <Axes: xlabel='Company', ylabel='Total Monthly Hours'>

# %%
#Q which are cities with highest electricity Bill
merge.groupby('City')['Electricity Bill'].sum().sort_values(ascending = False)
# Out:
# City
# Noida          6.171999e+06
# New Delhi      6.077629e+06
# Gurgaon        5.432612e+06
# Dahej          4.233663e+06
# Faridabad      4.172457e+06
# Ahmedabad      4.164610e+06
# Chennai        4.146522e+06
# Hyderabad      4.007731e+06
# Vadodara       3.761580e+06
# Nagpur         3.483118e+06
# Mumbai         3.417275e+06
# Navi Mumbai    3.195517e+06
# Pune           2.703679e+06
# Kolkata        2.447810e+06
# Ratnagiri      1.893492e+06
# Shimla         1.010045e+06
# Name: Electricity Bill, dtype: float64

# %%
plt.figure(figsize=(16,6),dpi=400)
sns.scatterplot(merge.groupby('City')['Electricity Bill'].sum().sort_values(ascending = False))
# Out:
# <Axes: xlabel='City', ylabel='Electricity Bill'>

# %%
sns.scatterplot(x=merge['Electicity Bill'],y = merge['Total Monthly Hours'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Electicity Bill'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2672083912.py in <cell line: 0>()
# ...

# %%
# in which city the electricity consumption is more for tata power than that of adani power
merge['Company'].unique()
# Out:
# array(['Indowind Energy', 'Orient Green', 'Tata Power Company Ltd.',
#        'Adani Power Ltd.', 'Reliance Energy'], dtype=object)

# %%
(merge['Company'] == 'Tata Power Company Ltd.' )|(merge['Company'] == 'Adani Power Ltd.')
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 6975     True
# 6976    False
# 6977    False
# 6978    False
# 6979     True
# Name: Company, Length: 6980, dtype: bool

# %%
merge[(merge['Company'] == 'Tata Power Company Ltd.' )|(merge['Company'] == 'Adani Power Ltd.')]
# Out:
#          Month       City                  Company  Total Monthly Hours  \
# 3     December  Ahmedabad  Tata Power Company Ltd.               393.60
# 4          May  Ahmedabad         Adani Power Ltd.               672.00
# 6          May  Ahmedabad  Tata Power Company Ltd.              1290.00
# 7     December  Ahmedabad  Tata Power Company Ltd.               310.40
# 8         July  Ahmedabad  Tata Power Company Ltd.              1821.00
# ...        ...        ...                      ...                  ...
# 6970      July   Vadodara  Tata Power Company Ltd.              2769.30
# 6971  December   Vadodara  Tata Power Company Ltd.               656.88
# 6973     April   Vadodara  Tata Power Company Ltd.              1259.70
# 6975  February   Vadodara         Adani Power Ltd.               771.12
# 6979  November   Vadodara  Tata Power Company Ltd.               979.20
#
#       TariffRate  Electricity Bill
# 3            7.9          3109.440
# ...

# %%
Result_Via_company = merge[(merge['Company'] == 'Tata Power Company Ltd.' )|(merge['Company'] == 'Adani Power Ltd.')]

# %%
Result_Via_company['Company'].unique()
# Out:
# array(['Tata Power Company Ltd.', 'Adani Power Ltd.'], dtype=object)

# %%
plt.figure(figsize=(16,10),dpi=400)
sns.barplot(x = Result_Via_company['Total Monthly Hours'],y = Result_Via_company['City'],hue = Result_Via_company['Company'])
# Out:
# <Axes: xlabel='Total Monthly Hours', ylabel='City'>

# %%
#which cities shows the Maximum range of usage?
plt.figure(figsize=(16,10),dpi=400)
sns.boxplot(x = merge['Total Monthly Hours'],y = merge['City'])
# Out:
# <Axes: xlabel='Total Monthly Hours', ylabel='City'>
